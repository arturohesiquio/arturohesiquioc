# %% [markdown]
# # Ejercicios de optimización escalar

# %% [markdown]
# ## Arturo Hesiquio Casarrubias     27/08/23

# %% [markdown]
# **Para la siguientes funciones encuentre los puntos críticos, grafique y diga si éste se trata de un máximo o mínimo, local o global.**

# %% [markdown]
# $f(x)=1260+117x-9x^2$

# %%
import sympy as sp
import numpy as np

sp.var("x")

def f(x) :
    return 1260 + 117*x - 9*x**2

df = sp.diff(f(x), x)

pc = sp.solve(df, x)
pc
# Out:
# [13/2]

# %%
ddf = sp.diff(df, x)
ddf
# Out:
# -18

# %%
import matplotlib.pyplot as plt
xn = np.linspace(0, 10, 1000)

plt.figure()
plt.plot(xn, f(xn))
for c in pc :
    plt.plot(c, f (c), "*r", ms=10)

# %% [markdown]
# El punto crítico en 6.5 es un máximo global

# %% [markdown]
# $f(x)=5+x+\frac{4}{x}$, para $x>0$

# %%
sp.var("x")

def f(x) :
    return 5 + x + (4/x)

df = sp.diff(f(x), x)

pc = sp.solve(df, x)
pc
# Out:
# [-2, 2]

# %%
import matplotlib.pyplot as plt
xn = np.linspace(0.9, 3, 1000)

plt.figure()
plt.plot(xn, f(xn))
for c in pc :
    plt.plot(c, f (c), "*r", ms=10)

# %% [markdown]
# La funcion tiene 1 punto crítico en 2
#
# El punto crítico en 2 es un mínimo global

# %% [markdown]
# $f(x)=6-2x+\sqrt{18-2x^2}$, para $-3\leq x\leq 3$

# %%
sp.var("x")

def f(x) :
    return 6 - (2*x) + (18-(2*(x**2)))**1/2

df = sp.diff(f(x), x)

pc = sp.solve(df, x)
pc
# Out:
# [-1]

# %%
import matplotlib.pyplot as plt
xn = np.linspace(-1.5, -0.5, 1000)

plt.figure()
plt.plot(xn, f(xn))
for c in pc :
    plt.plot(c, f (c), "*r", ms=10)

# %% [markdown]
# La funcion tiene 1 punto crítico en -1
#
# El punto crítico en -1 es un máximo global

# %% [markdown]
# $f(x)=\frac{1}{4}x^4+\frac{1}{3}x^3-x^2$ en el intervalo $[-3,1.7]$

# %%
sp.var("x")

def f(x) :
    return ((1/4)*x**4) + ((1/3)*x**3) - x**2

df = sp.diff(f(x), x)

pc = sp.solve(df, x)
pc
# Out:
# [-2.00000000000000, 0.0, 1.00000000000000]

# %%
import matplotlib.pyplot as plt
xn = np.linspace(-2.5, 2, 1000)

plt.figure()
plt.plot(xn, f(xn))
for c in pc :
    plt.plot(c, f (c), "*r", ms=10)

# %% [markdown]
# La funcion tiene 3 puntos críticos en -2, 0 y 1.
#
# - El punto crítico en -2 es un mínimo global.
# - El punto crítico en 0 es un máximo global.
# - El punto crítico en 1 es un mínimo local.

# %% [markdown]
# ---
# **Resuelva los siguientes problemas usando la librería `SymPy`. Use celdas en `Markdown` para explicar su procedimiento.**

# %% [markdown]
# El perímetro de un triángulo isósceles es de $10 cm$. ¿Cuánto deben medir sus lados para que el volumen del cuerpo generado por la rotación del triángulo en torno a su base sea el mayor posible? (Volumen de un cono $= \frac{1}{3}\pi r^2 h$, donde $r$ es el radio de la base y $h$ la altura del cono).

# %%
import sympy as sp

sp.var("x")
sp.var("y")

y = (10-x)/2

r = x/2

# %%
h = (y**2 -r **2)**(1/2)
h
# Out:
# (-x**2/4 + (5 - x/2)**2)**0.5

# %%
import numpy as np

V = (1/3)*np.pi*(r**2)*h

#Derivada
df = sp.diff(V,x)
#Puntos criticos
pc=sp.solve(df,x)
pc
# Out:
# [0.0, 4.00000000000000]

# %%
y=(10-4)/2
y
# Out:
# 3.0

# %% [markdown]
# La base es de 4 y los otros lados de 3

# %% [markdown]
# # Ejercicio 2

# %% [markdown]
# Disponemos de una barra de aluminio de 6 metros para construir una portería de fútbol. Si queremos que el área de la portería sea máxima, ¿cuánto deben medir los postes y el travesaño?

# %%
import sympy as sp

x = sp.symbols('x')
Area = x * (6 - 2 * x)

puntos_criticos = sp.solve(sp.diff(Area, x), x)

area_maxima = max([Area.subs(x, c) for c in puntos_criticos])

x_optimo = sp.solve(Area - area_maxima, x)
y_optimo = 6 - 2 * x_optimo[0]

print("Postes: ", x_optimo[0], "m")
print("Travesaño:",  y_optimo, "m")
# Out:
# Postes:  3/2 m
# Travesaño: 3 m
